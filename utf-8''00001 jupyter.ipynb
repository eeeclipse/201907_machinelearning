# %% [markdown]
# # Jupyter Tutorial
# ## 1. What is Jupyter Notebook?

# %% [markdown]
# The Jupyter Notebook is an open-source web application that allows you to create and share documents that contain live code, equations, visualizations and narrative text. Uses include: data cleaning and transformation, numerical simulation, statistical modeling, data visualization, machine learning, and much more.

# %% [markdown]
# ## 2. Live code example

# %%
3+4
# Out:
# 7

# %%
def add (a,b):
    return a+b

# %%
add(5,4)
# Out:
# 9

# %% [markdown]
# ## 3. Equation

# %%
#sqrt(x^2+y^2+z^2)

# %% [markdown]
# This expression $\sqrt(x^2+y^2+z^2)$ is an example of a TeX inline equation

# %% [markdown]
# [More Examples click here](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Typesetting%20Equations.html)

# %% [markdown]
# ## 4. Visualization
# ### 4.1 image

# %%
from IPython.display import Image
Image('https://notebooks.azure.com/Scripts/Jupyter/5.5.0/base/images/logo.png')

# %% [markdown]
# ### 4.2 video

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('vJwrhhL5f8Y')

# %% [markdown]
# ### 4.3 table

# %%
import pandas as pd
# pandas로 테이블 출력

url="https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
pd.read_csv(url, nrows=10)
# Out:
#                     Country  Region
# 0                   Algeria  AFRICA
# 1                    Angola  AFRICA
# 2                     Benin  AFRICA
# 3                  Botswana  AFRICA
# 4                   Burkina  AFRICA
# 5                   Burundi  AFRICA
# 6                  Cameroon  AFRICA
# 7                Cape Verde  AFRICA
# 8  Central African Republic  AFRICA
# 9                      Chad  AFRICA

# %% [markdown]
# ### 4.4 chart

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()
# Out:
# /home/nbuser/anaconda2_501/lib/python2.7/site-packages/matplotlib/font_manager.py:281: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %% [markdown]
# ## 5. Performance Check

# %%
# %timeit 3+4
# Out:
# 10000000 loops, best of 3: 56.8 ns per loop

# %%
# %timeit add(3,4)
# Out:
# 1000000 loops, best of 3: 407 ns per loop

# %%
# %%timeit
a = [1,2,3]
a = [x+1 for x in a]
# Out:
# 1000000 loops, best of 3: 1.45 µs per loop

# %%
# %%timeit
b = [1,2,3]
for i in range(len(b)):
    b[i] = b[1] + 1
# Out:
# The slowest run took 3259.61 times longer than the fastest. This could mean that an intermediate result is being cached.
# 100000 loops, best of 3: 2.14 µs per loop
